# %%
from ray.tune.registry import register_env
from glucose_env import CustomGlucoseDynamicsEnv
import ray
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.algorithms.dqn import DQNConfig
from ray.rllib.algorithms.impala import ImpalaConfig

def env_creator(env_config):
    """
    Returns a new instance of CustomGlucoseDynamicsEnv.
    """
    return CustomGlucoseDynamicsEnv()

env_name = "CustomGlucoseDynamicsEnv-v0"
register_env(env_name, env_creator)

ray.init()

num_of_iter = 8 

print("--- Starting Combined RL Training ---")

# PPO Training
print("\n--- Training PPO (Default Hyperparameters) ---")
ppo_config = (
    PPOConfig()
    .environment(env_name)
    .resources(num_gpus=1) 
    .framework("torch")
    .env_runners(num_env_runners=2) 
    .training(
        lr=0.00005, 
        train_batch_size_per_learner=4000, 
        num_epochs=30, 
        entropy_coeff=0.0,
        gamma=0.99, 
    )
    .evaluation(
        evaluation_interval=1,
        evaluation_duration=num_of_iter,
    )
)
ppo_algo = ppo_config.build()
for i in range(num_of_iter):
    result = ppo_algo.train()
    print(f"PPO Iteration {i} done")
ppo_algo.stop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 from glucose_env import CustomGlucoseDynamicsEnv
#       3 import ray
# ----> 4 from ray.rllib.algorithms.ppo import PPOConfig
#       5 from ray.rllib.algorithms.dqn import DQNConfig
#       6 from ray.rllib.algorithms.impala import ImpalaConfig
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/ray/rllib/__init__.py:7
#       3 from ray._private.usage import usage_lib
#       5 # Note: do not introduce unnecessary library dependencies here, e.g. gym.
#       6 # This file is imported from the tune module in order to register RLlib agents.
# ----> 7 from ray.rllib.env.base_env import BaseEnv
#       8 from ray.rllib.env.external_env import ExternalEnv
#       9 from ray.rllib.env.multi_agent_env import MultiAgentEnv
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/ray/rllib/env/__init__.py:1
# ----> 1 from ray.rllib.env.base_env import BaseEnv
#       2 from ray.rllib.env.env_context import EnvContext
#       3 from ray.rllib.env.external_env import ExternalEnv
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/ray/rllib/env/base_env.py:6
#       4 import gymnasium as gym
#       5 import ray
# ----> 6 from ray.rllib.utils.annotations import OldAPIStack
#       7 from ray.rllib.utils.typing import AgentID, EnvID, EnvType, MultiEnvDict
#       9 if TYPE_CHECKING:
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/ray/rllib/utils/__init__.py:9
#       7 from ray.rllib.utils.annotations import override, PublicAPI, DeveloperAPI
#       8 from ray.rllib.utils.deprecation import deprecation_warning
# ----> 9 from ray.rllib.utils.filter import Filter
#      10 from ray.rllib.utils.filter_manager import FilterManager
#      11 from ray.rllib.utils.framework import (
#      12     try_import_jax,
#      13     try_import_tf,
#      14     try_import_tfp,
#      15     try_import_torch,
#      16 )
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/ray/rllib/utils/filter.py:9
#       7 from ray.rllib.utils.annotations import OldAPIStack
#       8 from ray.rllib.utils.deprecation import Deprecated
# ----> 9 from ray.rllib.utils.numpy import SMALL_NUMBER
#      10 from ray.rllib.utils.typing import TensorStructType
#      11 from ray.rllib.utils.serialization import _serialize_ndarray, _deserialize_ndarray
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/ray/rllib/utils/numpy.py:15
#      12 from ray.rllib.utils.typing import SpaceStruct, TensorType, TensorStructType, Union
#      14 tf1, tf, tfv = try_import_tf()
# ---> 15 torch, _ = try_import_torch()
#      17 SMALL_NUMBER = 1e-6
#      18 # Some large int number. May be increased here, if needed.
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/ray/rllib/utils/framework.py:308, in try_import_torch(error)
#     305     return _torch_stubs()
#     307 try:
# --> 308     import torch
#     309     import torch.nn as nn
#     311     return torch, nn
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/__init__.py:2611
#    2607 from torch.func import vmap as vmap
#    2610 if not TYPE_CHECKING:
# -> 2611     from torch import _meta_registrations
#    2613 # Enable CUDA Sanitizer
#    2614 if "TORCH_CUDA_SANITIZER" in os.environ:
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_meta_registrations.py:12
#      10 import torch._prims_common as utils
#      11 from torch import SymBool, SymFloat, Tensor
# ---> 12 from torch._decomp import (
#      13     _add_op_to_registry,
#      14     _convert_out_params,
#      15     global_decomposition_table,
#      16     meta_table,
#      17 )
#      18 from torch._ops import OpOverload
#      19 from torch._prims import _prim_elementwise_meta, ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_decomp/__init__.py:276
#     272             decompositions.pop(op, None)
#     275 # populate the table
# --> 276 import torch._decomp.decompositions
#     277 import torch._refs
#     280 def core_aten_decompositions() -> "CustomDecompTable":
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_decomp/decompositions.py:16
#      14 import torch
#      15 import torch._meta_registrations
# ---> 16 import torch._prims as prims
#      17 import torch._prims_common as utils
#      18 import torch.nn.functional as F
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_prims/__init__.py:525
#     517     raise NotImplementedError
#     520 #
#     521 # Elementwise unary operations
#     522 #
# --> 525 abs = _make_elementwise_unary_prim(
#     526     "abs",
#     527     impl_aten=torch.abs,
#     528     doc="",
#     529     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.COMPLEX_TO_FLOAT,
#     530 )
#     532 acos = _make_elementwise_unary_prim(
#     533     "acos",
#     534     impl_aten=torch.acos,
#     535     doc="",
#     536     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     537 )
#     539 acosh = _make_elementwise_unary_prim(
#     540     "acosh",
#     541     impl_aten=torch.acosh,
#     542     doc="",
#     543     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     544 )
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_prims/__init__.py:493, in _make_elementwise_unary_prim(name, type_promotion, **kwargs)
#     486 def _make_elementwise_unary_prim(
#     487     name: str, *, type_promotion: ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND, **kwargs
#     488 ):
#     489     """
#     490     Creates an elementwise unary prim.
#     491     """
# --> 493     return _make_prim(
#     494         schema=f"{name}(Tensor self) -> Tensor",
#     495         meta=partial(_prim_elementwise_meta, type_promotion=type_promotion),
#     496         return_type=RETURN_TYPE.NEW,
#     497         **kwargs,
#     498     )
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_prims/__init__.py:321, in _make_prim(schema, return_type, meta, impl_aten, doc, tags, use_old_custom_ops_api, register_conj_neg_fallthrough)
#     315 else:
#     316     mutates_args = [
#     317         arg.name
#     318         for arg in cpp_schema.arguments
#     319         if arg.alias_info is not None and arg.alias_info.is_write
#     320     ]
# --> 321     prim_def = torch.library.custom_op(
#     322         "prims::" + name,
#     323         _prim_impl,
#     324         mutates_args=tuple(mutates_args),
#     325         schema=schema,
#     326     )
#     327     prim_def.register_fake(meta)
#     329     # all view ops get conj/neg fallthroughs
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_library/custom_ops.py:173, in custom_op(name, fn, mutates_args, device_types, schema)
#     171 if fn is None:
#     172     return inner
# --> 173 return inner(fn)
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_library/custom_ops.py:154, in custom_op.<locals>.inner(fn)
#     151     schema_str = schema
#     153 namespace, opname = name.split("::")
# --> 154 result = CustomOpDef(namespace, opname, schema_str, fn)
#     155 if schema is not None:
#     156     # Check that schema's alias annotations match those of `mutates_args`.
#     157     expected = set()
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_library/custom_ops.py:204, in CustomOpDef.__init__(self, namespace, name, schema, fn)
#     201 self._autocast_cpu_dtype: Optional[_dtype] = None
#     203 self._lib = get_library_allowing_overwrite(self._namespace, self._name)
# --> 204 self._register_to_dispatcher()
#     205 self._disabled_kernel: set = set()
#     206 OPDEFS[self._qualname] = self
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_library/custom_ops.py:624, in CustomOpDef._register_to_dispatcher(self)
#     616         raise RuntimeError(
#     617             f"There was no fake impl registered for {self}. "
#     618             f"This is necessary for torch.compile/export/fx tracing to work. "
#     619             f"Please use `{self._init_fn.__name__}.register_fake` to add an "
#     620             f"fake impl."
#     621         )
#     622     return self._abstract_fn(*args, **kwargs)
# --> 624 lib._register_fake(self._name, fake_impl, _stacklevel=4)
#     626 autograd_impl = autograd.make_autograd_impl(self._opoverload, self)
#     627 lib.impl(self._name, autograd_impl, "Autograd", with_keyset=True)
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/library.py:193, in Library._register_fake(self, op_name, fn, _stacklevel)
#     190     _library.utils.warn_deploy()
#     191     return
# --> 193 source = torch._library.utils.get_source(_stacklevel + 1)
#     194 frame = sys._getframe(_stacklevel)
#     195 caller_module = inspect.getmodule(frame)
#
# File /mnt/c/Users/USER/Study/Y2S3/ML/Assignment/Ongoing/.venv/lib/python3.12/site-packages/torch/_library/utils.py:54, in get_source(stacklevel)
#      45 def get_source(stacklevel: int) -> str:
#      46     """Get a string that represents the caller.
#      47
#      48     Example: "/path/to/foo.py:42"
#    (...)     52     etc.
#      53     """
# ---> 54     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#      55     source = f"{frame.filename}:{frame.lineno}"
#      56     return source
#
# File /usr/lib/python3.12/inspect.py:1707, in getframeinfo(frame, context)
#    1705 start = lineno - 1 - context//2
#    1706 try:
# -> 1707     lines, lnum = findsource(frame)
#    1708 except OSError:
#    1709     lines = index = None
#
# File /usr/lib/python3.12/inspect.py:1083, in findsource(object)
#    1080     if not (file.startswith('<') and file.endswith('>')):
#    1081         raise OSError('source code not available')
# -> 1083 module = getmodule(object, file)
#    1084 if module:
#    1085     lines = linecache.getlines(file, module.__dict__)
#
# File /usr/lib/python3.12/inspect.py:1006, in getmodule(object, _filename)
#    1004     continue
#    1005 _filesbymodname[modname] = f
# -> 1006 f = getabsfile(module)
#    1007 # Always map to the name the module knows itself by
#    1008 modulesbyfile[f] = modulesbyfile[
#    1009     os.path.realpath(f)] = module.__name__
#
# File /usr/lib/python3.12/inspect.py:975, in getabsfile(object, _filename)
#     970 """Return an absolute path to the source or compiled file for an object.
#     971
#     972 The idea is for each object to have a unique origin, so this routine
#     973 normalizes the result as much as possible."""
#     974 if _filename is None:
# --> 975     _filename = getsourcefile(object) or getfile(object)
#     976 return os.path.normcase(os.path.abspath(_filename))
#
# File /usr/lib/python3.12/inspect.py:960, in getsourcefile(object)
#     958 if filename in linecache.cache:
#     959     return filename
# --> 960 if os.path.exists(filename):
#     961     return filename
#     962 # only return a non-existent filename if the module has a PEP 302 loader
#
# File <frozen genericpath>:19, in exists(path)
#
# KeyboardInterrupt:

# %%
# DQN (Double Q-learning) Training Needs to be CHANGED
print("\n--- Training DQN (Default Hyperparameters) ---")
dqn_config = (
    DQNConfig()
    .environment(env_name)
    .resources(num_gpus=1) 
    .framework("torch")
    .env_runners(num_env_runners=2)
    .training(
        lr=0.00005,
        train_batch_size=30,
        double_q=True,
    ) 
    .evaluation(
        evaluation_interval=1,
        evaluation_duration=num_of_iter,
    )
)
dqn_algo = dqn_config.build()
for i in range(num_of_iter):
    result = dqn_algo.train()
    print(f"DQN Iteration {i} done")
dqn_algo.stop()

# %%
# IMPALA Training 
print("\n--- Training IMPALA (Default Hyperparameters) ---")
impala_config = (
    ImpalaConfig()
    .environment(env_name)
    .resources(
        num_gpus=1, 
        num_learner_workers=1 
    )
    .framework("torch")
    .env_runners(num_env_runners=2) 
    .evaluation(
        evaluation_interval=1,
        evaluation_duration=num_of_iter,
    )
)
impala_algo = impala_config.build()
for i in range(num_of_iter):
    result = impala_algo.train()
    print(f"IMPALA Iteration {i} done")
impala_algo.stop()

# %%
# Recurrent PPO Training
print("\n--- Training Recurrent PPO (Default Hyperparameters) ---")
recurrent_ppo_config = (
    PPOConfig() 
    .environment(env_name)
    .resources(num_gpus=1) 
    .framework("torch")
    .env_runners(num_env_runners=2) 
    .training(
        lr=0.00005,
        train_batch_size_per_learner=4000, 
        num_epochs=30,
        entropy_coeff=0.0, 
        gamma=0.99, 
        model={
            "use_lstm": True, 
            "lstm_cell_size": 256, 
            "max_seq_len": 20, 
        },
    )
    .evaluation(
        evaluation_interval=1,
        evaluation_duration=num_of_iter,
    )
)
recurrent_ppo_algo = recurrent_ppo_config.build()
for i in range(num_of_iter):
    result = recurrent_ppo_algo.train()
    print(f"Recurrent PPO Iteration {i} done")
recurrent_ppo_algo.stop()

ray.shutdown()
print("\n--- All training complete ---")
